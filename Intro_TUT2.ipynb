# %% [markdown]
#  GPU version
# we start by using
# 1)reset all Runtimes
# 2)Notebook Settings
# 3)!pip install tensorflow--gpu

# %%
# !pip install tensorflow--gpu
# Out:
# ...
#      |████████████████████████████████| 345.2MB 49kB/s
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.13.1
